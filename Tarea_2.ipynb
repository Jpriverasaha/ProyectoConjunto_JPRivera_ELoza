# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:**Juan Pablo Rivera y Eduardo Loza
#
# **Fecha:** 09 de septiembre del 2020.
#
# **Expediente** : If714314 e IF713423
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# # Tarea 2: Clase x

# %% [markdown]
# https://github.com/Jpriverasaha/ProyectoConjunto_JPRivera_ELoza

# %% [markdown]
# https://github.com/Jpriverasaha/ProyectoConjunto_JPRivera_ELoza/blob/master/Tarea_2.ipynb

# %% [markdown]
# 1. Imagine una rutina contable utilizada en una librería. Funciona en una lista con sublistas, que se ven así:
# ![image.png](attachment:image.png)
# Escriba un programa en Python, que devuelve una lista con tuplas de tamaño 2. Cada tupla consiste en el número de pedido y el costo total del pedido. El producto debe aumentarse en 10€ si el valor de la orden es inferior a 100,00 €.
# Escribe un programa Python usando unicamente las funciones **lambda y map**.
#
# `orders = [ ["34587", "Learning Python, Mark Lutz", 4, 40.95],
#            ["98762", "Programming Python, Mark Lutz", 5, 56.80],
#            ["77226", "Head First Python, Paul Barry", 3,32.95],
#            ["88112", "Einführung in Python3, Bernd Klein", 3, 24.99]]`
#
#
# 2. La misma librería, pero esta vez trabajamos en una lista diferente. Las sublistas de nuestras listas se ven así:
# [número de orden, (número de artículo, cantidad, precio por unidad), ... (número de artículo, cantidad, precio por unidad)]
#
# `orders = [[1, ("5464", 4, 9.99), ("8274",18,12.99), ("9744", 9, 44.95)],
# 	       [2, ("5464", 9, 9.99), ("9744", 9, 44.95)],
# 	       [3, ("5464", 9, 9.99), ("88112", 11, 24.99)],
#            [4, ("8732", 7, 11.99), ("7733",11,18.99), ("88112", 5, 39.95)] ]`
#
# Escriba un programa que devuelva una lista de dos tuplas que tengan la información de (número de pedido, cantidad total de pedido). Utilice la función `Reduce`. Recuerde el precio del pedido del producto debe aumentarse en 10€ si el valor de la orden es inferior a 100,00 €.
#
# 3. Resolver los anteriores ejercicios usando pandas (DataFrame)

# %%
from functools import reduce
import numpy as np
import pandas as pd
from pandas import DataFrame

# %%
orders = [ ["34587", "Learning Python, Mark Lutz", 4, 40.95], 
           ["98762", "Programming Python, Mark Lutz", 5, 56.80], 
           ["77226", "Head First Python, Paul Barry", 3,32.95],
           ["88112", "Einführung in Python3, Bernd Klein", 3, 24.99]]

# %%
##1 Juan Pablo
p=lambda x, y:x*y
def increase(value):
    if value < 100:
        value +=10
    return value
x=list(map(increase,[p(orders[i][2],orders[i][3]) for i in np.arange(len(orders))]))
result1=list(map(lambda x,y:(x[0],y),orders,x))
result1
# Out:
# [('34587', 163.8),
#  ('98762', 284.0),
#  ('77226', 108.85000000000001),
#  ('88112', 84.97)]

# %%
#Eduardo Loza
orders1 = [ ["34587", "Learning Python, Mark Lutz", 4, 40.95], 
           ["98762", "Programming Python, Mark Lutz", 5, 56.80], 
           ["77226", "Head First Python, Paul Barry", 3,32.95],
           ["88112", "Einführung in Python3, Bernd Klein", 3, 24.99]]
import numpy as np
p=lambda x,y:x*y
def aum(value):
    if(value<100):
        value+=10
    return value
mult=list(map(aum,[p(orders1[i][2],orders1[i][3]) for i in np.arange(len(orders1))]))
mult

result=list(map(lambda x,y: (x[0],y),orders1,mult))
result
p=lambda x,y:x*y
def aum(value):
    if(value<100):
        value+=10
    return value
mult=list(map(aum,[p(orders1[i][2],orders1[i][3]) for i in np.arange(len(orders1))]))
mult

result=list(map(lambda x,y: (x[0],y),orders1,mult))
result
# Out:
# [('34587', 163.8),
#  ('98762', 284.0),
#  ('77226', 108.85000000000001),
#  ('88112', 84.97)]

# %%
#3 Juan Pablo
data= pd.DataFrame(result1)
data
# Out:
#        0       1
# 0  34587  163.80
# 1  98762  284.00
# 2  77226  108.85
# 3  88112   84.97

# %%
##2 Juan Pablo
orders2 = [[1, ("5464", 4, 9.99), ("8274",18,12.99), ("9744", 9, 44.95)], 
       [2, ("5464", 9, 9.99), ("9744", 9, 44.95)],
       [3, ("5464", 9, 9.99), ("88112", 11, 24.99)],
       [4, ("8732", 7, 11.99), ("7733",11,18.99), ("88112", 5, 39.95)] ]

# %%
from functools import reduce

# %%
o1=list(map(increase,[p(orders2[0][i+1][1],orders2[0][i+1][2]) for i in np.arange(3)]))
o2=list(map(increase,[p(orders2[1][i+1][1],orders2[1][i+1][2]) for i in np.arange(2)]))
o3=list(map(increase,[p(orders2[2][i+1][1],orders2[2][i+1][2]) for i in np.arange(2)]))
o4=list(map(increase,[p(orders2[3][i+1][1],orders2[3][i+1][2]) for i in np.arange(3)]))
o1=reduce(lambda x,y:x+y,o1)
o2=reduce(lambda x,y:x+y,o2)
o3=reduce(lambda x,y:x+y,o3)
o4=reduce(lambda x,y:x+y,o4)
x=[o1,o2,o3,o4]
result2=list(map(lambda x,y:(x[0],y),orders2,x))
result2
# Out:
# [(1, 688.3299999999999),
#  (2, 504.46000000000004),
#  (3, 374.79999999999995),
#  (4, 502.57)]

# %%
## 2 Eduardo
orders2 = [[1, ("5464", 4, 9.99), ("8274",18,12.99), ("9744", 9, 44.95)], 
          [2, ("5464", 9, 9.99), ("9744", 9, 44.95)],
          [3, ("5464", 9, 9.99), ("88112", 11, 24.99)],
          [4, ("8732", 7, 11.99), ("7733",11,18.99), ("88112", 5, 39.95)] ]

minimo = 100
total = list(map(lambda x: [x[0]] + list(map(lambda y: y[1]*y[2] 
                    if y[1]*y[2]>=minimo else y[1]*y[2] +10 , x[1:])), orders2))

total = list(map(lambda x: [x[0]] + \
                 [reduce(lambda a,b: a + b, x[1:])], total))

print (total)
# Out:
# [[1, 688.3299999999999], [2, 504.46000000000004], [3, 374.79999999999995], [4, 502.57]]

# %%
#3 Juan Pablo
data1= pd.DataFrame(result1,columns=["Order number","Total"])
data1
# Out:
#   Order number   Total
# 0        34587  163.80
# 1        98762  284.00
# 2        77226  108.85
# 3        88112   84.97

# %%
## Juan Pablo
data2= pd.DataFrame(result2,columns=["Numero de orden","Total"])
data2
# Out:
#    Numero de orden   Total
# 0                1  688.33
# 1                2  504.46
# 2                3  374.80
# 3                4  502.57

# %% [markdown]
# 4. Use filter to eliminate all words that are shorter than 4 letters from a list of words
# `list='the notion of a lambda function goes all the way back to the origin of computer science'`

# %%
##3 Eduardo

result1 = pd.DataFrame(result)
result1 = result1.set_index(result1[0])
result1 = result1.drop(result1.columns[[0]], axis='columns')
print(result1)
total1= pd.DataFrame(total)
total1 = total1.set_index(total1[0])
total1 = total1.drop(total1.columns[[0]], axis='columns')
print(total1)
# Out:
#             1
# 0
# 34587  163.80
# 98762  284.00
# 77226  108.85
# 88112   84.97
#         1
# 0
# 1  688.33
# 2  504.46
# 3  374.80
# 4  502.57

# %%
list1="the notion of a lambda function goes all the way back to the origin of computer science"

# %%
# Juan Pablo
l1=list1.split()
l1
r=list(filter(lambda x: len(x)>4, l1))
r
# Out:
# ['notion', 'lambda', 'function', 'origin', 'computer', 'science']

# %%
# 4 Eduardo
lista ='the notion of a lambda function goes all the way back to the origin of computer science'.split()
lista

res = filter((lambda x: len(x) >= 4), lista)
print(list(res))
# Out:
# ['notion', 'lambda', 'function', 'goes', 'back', 'origin', 'computer', 'science']

# %% [markdown]
# 5. Use filter to determine the percentage of Fahrenheit temperatures in a list are within the range 32 to 80

# %%
import numpy as np
np.random.seed(55555)
temperatures = np.random.uniform(25,110,30)
print(temperatures)
# Out:
# [ 35.97387961  99.13294268  92.6178302   99.69549478  63.21119535
#   73.90387697  95.50028838  99.21476553  36.98251238 101.45813729
#  100.5917418   89.38159435  89.52156589  83.8084752   28.37990868
#   68.75395211  45.86132067  36.58307493  56.32208365  33.96219302
#   45.29071318  74.86289938  66.51091383  88.19316186  94.26635864
#   46.83131624 109.60744472 109.68427993  44.55796499  92.84146259]

# %%
## Juan Pablo
r=list(filter(lambda x: (32< x < 80) , temperatures))
porcentaje=(len(r)/len(list(temperatures)))

r, porcentaje*100
# Out:
# ([35.97387961379455,
#   63.211195349983264,
#   73.90387696517755,
#   36.982512376595906,
#   68.75395211338406,
#   45.86132066984196,
#   36.58307493022292,
#   56.322083650154724,
#   33.9621930206693,
#   45.29071317816652,
#   74.86289938282341,
#   66.51091382521807,
#   46.831316244170544,
#   44.55796498523391],
#  46.666666666666664)

# %%
# 5 Eduardo

lista= filter(lambda x:x>=32 and x<=80,temperatures)
print('El porcentaje de temperaturas entre 32 y 80 es:%.2f porciento' %((len(list(lista))/len(temperatures))*100))
# Out:
# El porcentaje de temperaturas entre 32 y 80 es:46.67 porciento

# %% [markdown]
# 6. Use reduce to find the lower left corner (minimum x and minimum y value) for a list of point locations
# > **Hint**: Explore the command `np.minimum.reduce` [link](https://docs.scipy.org/doc/numpy/reference/generated/numpy.ufunc.reduce.html)

# %%
np.random.seed(55555)
point_xy = np.random.randint(0,100,[30,2])
print(point_xy)
# Out:
# [[17 97]
#  [22 33]
#  [37 46]
#  [57 28]
#  [11 25]
#  [14  2]
#  [74 16]
#  [12 37]
#  [35 21]
#  [66 65]
#  [86 58]
#  [67 81]
#  [ 0 48]
#  [28 66]
#  [76 22]
#  [46 47]
#  [64  7]
#  [88 94]
#  [65 13]
#  [75 89]
#  [23 17]
#  [36 63]
#  [62 36]
#  [64 17]
#  [18 19]
#  [88 41]
#  [21 49]
#  [98 36]
#  [81 73]
#  [62 90]]

# %%
## Juan Pablo
r=np.minimum.reduce(point_xy)
r
# Out:
# array([0, 2])

# %%
# 6 Eduardo


x = np.minimum.reduce(point_xy)
x
# Out:
# array([0, 2])
